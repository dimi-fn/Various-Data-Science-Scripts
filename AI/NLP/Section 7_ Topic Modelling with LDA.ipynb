# %%
import numpy as np
import pandas as pd

# Code to read csv file into colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
'''
downloaded = drive.CreateFile({'id':'1q9Yh9GorYkl_xf3O_P4zBbPYBXtTcuWx'}) 
downloaded.GetContentFile('moviereviews.tsv') 

df= pd.read_csv("moviereviews.tsv", sep='\t')

df.head()

'''
# Out:
# '\ndownloaded = drive.CreateFile({\'id\':\'1q9Yh9GorYkl_xf3O_P4zBbPYBXtTcuWx\'}) \ndownloaded.GetContentFile(\'moviereviews.tsv\') \n\ndf= pd.read_csv("moviereviews.tsv", sep=\'\t\')\n\ndf.head()\n\n'

# %%
# for the theory of LDA go to udemy s7L3

# %% [markdown]
# # Topic Modelling
#
# It allows for us to efficiently analyse large volumes of text by clustering documents into topics

# %% [markdown]
# # Latent Dirichlet Allocation - LDA

# %% [markdown]
# Data
#
# We will be using articles from NPR (National Public Radio), obtained from their website [www.npr.org](http://www.npr.org)

# %%
downloaded = drive.CreateFile({'id':'1N8lD07IGqQnEQMvvc0NEogtZNPpT3Bw2'}) 
downloaded.GetContentFile('npr.csv') 

articles= pd.read_csv("npr.csv")

articles.head()

# Notice how we don't have the topic of the articles! 
# Let's use LDA to attempt to figure out clusters of the articles.
# Out:
#                                              Article
# 0  In the Washington of 2016, even when the polic...
# 1    Donald Trump has used Twitter  —   his prefe...
# 2    Donald Trump is unabashedly praising Russian...
# 3  Updated at 2:50 p. m. ET, Russian President Vl...
# 4  From photography, illustration and video, to d...

# %%
articles.shape
# Out:
# (11992, 1)

# %%
articles['Article'][0]
# Out:
# 'In the Washington of 2016, even when the policy can be bipartisan, the politics cannot. And in that sense, this year shows little sign of ending on Dec. 31. When President Obama moved to sanction Russia over its alleged interference in the U. S. election just concluded, some Republicans who had long called for similar or more severe measures could scarcely bring themselves to approve. House Speaker Paul Ryan called the Obama measures ”appropriate” but also ”overdue” and ”a prime example of this administration’s ineffective foreign policy that has left America weaker in the eyes of the world.” Other GOP leaders sounded much the same theme. ”[We have] been urging President Obama for years to take strong action to deter Russia’s worldwide aggression, including its   operations,” wrote Rep. Devin Nunes,  . chairman of the House Intelligence Committee. ”Now with just a few weeks left in office, the president has suddenly decided that some stronger measures are indeed warranted.” Appearin
# ...

# %%
# Below we are displaying the text as a script which is more readable (not like above)
from IPython.display import Markdown, display
display(Markdown('> '+articles['Article'][0]))
# Out:
# > In the Washington of 2016, even when the policy can be bipartisan, the politics cannot. And in that sense, this year shows little sign of ending on Dec. 31. When President Obama moved to sanction Russia over its alleged interference in the U. S. election just concluded, some Republicans who had long called for similar or more severe measures could scarcely bring themselves to approve. House Speaker Paul Ryan called the Obama measures ”appropriate” but also ”overdue” and ”a prime example of this administration’s ineffective foreign policy that has left America weaker in the eyes of the world.” Other GOP leaders sounded much the same theme. ”[We have] been urging President Obama for years to take strong action to deter Russia’s worldwide aggression, including its   operations,” wrote Rep. Devin Nunes,  . chairman of the House Intelligence Committee. ”Now with just a few weeks left in office, the president has suddenly decided that some stronger measures are indeed warranted.” Appeari
# ...

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# **`max_df`**` : float in range [0.0, 1.0] or int, default=1.0`<br>
# When building the vocabulary ignore terms that have a document frequency strictly higher than the given threshold (corpus-specific stop words). If float, the parameter represents a proportion of documents, integer absolute counts. This parameter is ignored if vocabulary is not None.
#
# **`min_df`**` : float in range [0.0, 1.0] or int, default=1`<br>
# When building the vocabulary ignore terms that have a document frequency strictly lower than the given threshold. This value is also called cut-off in the literature. If float, the parameter represents a proportion of documents, integer absolute counts. This parameter is ignored if vocabulary is not None.

# %% [markdown]
# > We are not going to split train/test, because this is unsupervised learning: we dont have labels
#
# >> so for this reason we are going to apply fit transform through the entire dataset via unsupervised learning

# %%
# max_df -> [0,1] ignoring words with high document frequency, the higher the number the more you ignore
# it will will discard words which appear in 95% of documents

# min_df-> [0,1] or int=raw number of documents, minimun document frequency 
# here min_df=2 => words much appear at least in 2 documtns

# it will remove stopwods

cv = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')

# Document Term Martix
dtm = cv.fit_transform(articles['Article']) 
dtm
# Out:
# <11992x54777 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3033388 stored elements in Compressed Sparse Row format>

# %% [markdown]
# > This means 11,992 articles with 54,777 terms each

# %% [markdown]
# ## LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation


# documentation: n_components int, optional (default=10)
# we state we want number of topics= 7!!!!! we are free to set whatever
# we randomly assign words in the beginning, so we want to make sure we apply randomness
LDA = LatentDirichletAllocation(n_components=7,random_state=42)


# This can take awhile, we're dealing with a large amount of documents!
# fit LDA to our Document Term Matrix
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=7, n_jobs=None,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %% [markdown]
# ### 3 more tasks now
#
# 1) Grab the vocabulary of words
#
# 2) Grab the topics
#
# 3) Grab the highest probability words per topics

# %% [markdown]
# ### Showing Stored Words - Grab the vocabulary of words (1)

# %%
len(cv.get_feature_names()) # the terms/words of the sparse matrix
# Out:
# 54777

# %%
import random

for index in range(10):
    random_word_id = random.randint(0, 54777)
    print(cv.get_feature_names()[random_word_id])
# Out:
# statehood
# polymorphous
# chuckles
# imbued
# pinballing
# tight
# nsc
# treatable
# contrast
# convenient

# %%
for i in range(10):
    random_word_id = random.randint(0,54776)
    print(cv.get_feature_names()[random_word_id])
# Out:
# nappy
# winding
# circling
# ebro
# costar
# payers
# exodus
# nydia
# maladies
# mortgage

# %% [markdown]
# ### Showing Top Words Per Topic - Grab the topics (2)

# %%
len(LDA.components_) # we had declared 7 topics
# Out:
# 7

# %%
LDA.components_ # it contains probabilities for each word
# Out:
# array([[8.64332806e+00, 2.38014333e+03, 1.42900522e-01, ...,
#         1.43006821e-01, 1.42902042e-01, 1.42861626e-01],
#        [2.76191749e+01, 5.36394437e+02, 1.42857148e-01, ...,
#         1.42861973e-01, 1.42857147e-01, 1.42906875e-01],
#        [7.22783888e+00, 8.24033986e+02, 1.42857148e-01, ...,
#         6.14236247e+00, 2.14061364e+00, 1.42923753e-01],
#        ...,
#        [3.11488651e+00, 3.50409655e+02, 1.42857147e-01, ...,
#         1.42859912e-01, 1.42857146e-01, 1.42866614e-01],
#        [4.61486388e+01, 5.14408600e+01, 3.14281373e+00, ...,
#         1.43107628e-01, 1.43902481e-01, 2.14271779e+00],
#        [4.93991422e-01, 4.18841042e+02, 1.42857151e-01, ...,
#         1.42857146e-01, 1.43760101e-01, 1.42866201e-01]])

# %%
LDA.components_.shape
# Out:
# (7, 54777)

# %% [markdown]
# ### Grab the highest probability words per topics (3) - By combining (1) & (2)

# %%
len(LDA.components_[0])
# Out:
# 54777

# %%
single_topic = LDA.components_[0]

# %%
# to understand arg

arr= np.array([10,200,1])
arr
# Out:
# array([ 10, 200,   1])

# %%
arr.argsort() # it changes the index positions from the lowest to the highest value/ sorting in ascending order of the values
# Out:
# array([2, 0, 1])

# %%
# Returns the indices (index positions) that would sort this array.
single_topic.argsort()

# we want to locate the indices of these topics (LDA components)
#  because they are correlated with the index positions of vobac of words (LDAfeature names)
# Out:
# array([ 2475, 18302, 35285, ..., 22673, 42561, 42993])

# %%
# Word least representative of this topic
single_topic[18302]
# Out:
# 0.14285714309286987

# %%
# Word most representative of this topic
single_topic[42993]
# Out:
# 6247.245510521098

# %%
# Top 10 words for this topic:

# remember: arg.sort returns the index positions sorted from least-> greatest
single_topic.argsort()[-10:]
# Out:
# array([33390, 36310, 21228, 10425, 31464,  8149, 36283, 22673, 42561,
#        42993])

# %%
top_ten_word_indices = single_topic.argsort()[-10:]

for index in top_ten_word_indices:
    print(cv.get_feature_names()[index])

# these words tend to have some sort of generalised topic feeling   

# so here LDA is now showing us some sort of underlying latent topic:
# these particular words have high probabilities of showing up in this particular single topic: single_topic.argsort()[-10:]
# Out:
# new
# percent
# government
# company
# million
# care
# people
# health
# said
# says

# %% [markdown]
# These look like business articles perhaps... Let's confirm by using .transform() on our vectorized articles to attach a label number. But first, let's view all the 10 topics found.

# %%
# top 15 words for each of the 7 topics
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names()[index] for index in topic.argsort()[-15:]]) # in descending order
    print('\n')


# probabilities of words belonging to a particular topic
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['companies', 'money', 'year', 'federal', '000', 'new', 'percent', 'government', 'company', 'million', 'care', 'people', 'health', 'said', 'says']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['military', 'house', 'security', 'russia', 'government', 'npr', 'reports', 'says', 'news', 'people', 'told', 'police', 'president', 'trump', 'said']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['way', 'world', 'family', 'home', 'day', 'time', 'water', 'city', 'new', 'years', 'food', 'just', 'people', 'like', 'says']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['time', 'new', 'don', 'years', 'medical', 'disease', 'patients', 'just', 'children', 'study', 'like', 'women', 'health', 'people', 'says']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['voters', 'vote', 'election', 'party', 'new', 'obama', 'court', 'republican', 'campaign', 'people', 'state', 'president', 'clinton', 'said', 'trump']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ...

# %% [markdown]
# ### Attaching Discovered Topic Labels to Original Articles

# %%
dtm
# Out:
# <11992x54777 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3033388 stored elements in Compressed Sparse Row format>

# %%
dtm.shape
# Out:
# (11992, 54777)

# %%
len(articles)
# Out:
# 11992

# %%
topic_results = LDA.transform(dtm)

topic_results.shape
# Out:
# (11992, 7)

# %%
topic_results[0]
# Out:
# array([1.61040465e-02, 6.83341493e-01, 2.25376318e-04, 2.25369288e-04,
#        2.99652737e-01, 2.25479379e-04, 2.25497980e-04])

# %%
topic_results[0].round(2)
# Out:
# array([0.02, 0.68, 0.  , 0.  , 0.3 , 0.  , 0.  ])

# %%
topic_results[0].argmax()
# Out:
# 1

# %% [markdown]
# This means that our model thinks that the first article belongs to topic #1.

# %% [markdown]
# ### Combining with Original Data

# %%
articles.head()
# Out:
#                                              Article
# 0  In the Washington of 2016, even when the polic...
# 1    Donald Trump has used Twitter  —   his prefe...
# 2    Donald Trump is unabashedly praising Russian...
# 3  Updated at 2:50 p. m. ET, Russian President Vl...
# 4  From photography, illustration and video, to d...

# %%
# procedure for addding a column in our original dataset for reflecting the topics
topic_results = LDA.transform(dtm)
topic_results
# Out:
# array([[1.61040465e-02, 6.83341493e-01, 2.25376318e-04, ...,
#         2.99652737e-01, 2.25479379e-04, 2.25497980e-04],
#        [3.63424997e-02, 8.86130697e-01, 4.40751747e-04, ...,
#         7.57636804e-02, 4.40866779e-04, 4.40835574e-04],
#        [3.28569485e-04, 6.96344889e-01, 3.28302105e-04, ...,
#         3.02012902e-01, 3.28724083e-04, 3.28352652e-04],
#        ...,
#        [1.44467964e-02, 1.60696622e-01, 1.73678310e-01, ...,
#         2.24636569e-02, 3.98728349e-04, 3.98359730e-04],
#        [4.33560738e-04, 3.53196803e-02, 4.33022554e-04, ...,
#         9.62512640e-01, 4.33971991e-04, 4.33490254e-04],
#        [3.98777533e-01, 2.54376049e-04, 3.59290659e-01, ...,
#         2.40914375e-01, 2.54445555e-04, 2.54253739e-04]])

# %%
# probabilities of documents belonging to a particular topic

# (remember more above we saw probabilities of words belonging to a topic)
topic_results[0]

# for example 1.61040465e-02 = the probability of topic 0 index 0 and so on
# these probabiity number are in range [0,1]
# Out:
# array([1.61040465e-02, 6.83341493e-01, 2.25376318e-04, 2.25369288e-04,
#        2.99652737e-01, 2.25479379e-04, 2.25497980e-04])

# %%
# in round 2

topic_results[0].round(2)



# for example this article with index 0, has high probability (68%) belonging to topic#1, because 0.68 is index #1

# let's see if it makes sense:
# 1)
# more above you can find that the top words for topic #1 are:
#THE TOP 15 WORDS FOR TOPIC #1
#['military', 'house', 'security', 'russia', 'government', 'npr', 'reports', 'says', 'news', 'people', 'told', 'police', 'president', 'trump', 'said']

# 2)
# print articles['Articles'][0] and see if the above words make send to this article
# Out:
# array([0.02, 0.68, 0.  , 0.  , 0.3 , 0.  , 0.  ])

# %%
articles['Article'][0]
# Out:
# 'In the Washington of 2016, even when the policy can be bipartisan, the politics cannot. And in that sense, this year shows little sign of ending on Dec. 31. When President Obama moved to sanction Russia over its alleged interference in the U. S. election just concluded, some Republicans who had long called for similar or more severe measures could scarcely bring themselves to approve. House Speaker Paul Ryan called the Obama measures ”appropriate” but also ”overdue” and ”a prime example of this administration’s ineffective foreign policy that has left America weaker in the eyes of the world.” Other GOP leaders sounded much the same theme. ”[We have] been urging President Obama for years to take strong action to deter Russia’s worldwide aggression, including its   operations,” wrote Rep. Devin Nunes,  . chairman of the House Intelligence Committee. ”Now with just a few weeks left in office, the president has suddenly decided that some stronger measures are indeed warranted.” Appearin
# ...

# %%
# Below we are displaying the text as a script which is more readable (not like above)
from IPython.display import Markdown, display
display(Markdown('> '+articles['Article'][0]))
# Out:
# > In the Washington of 2016, even when the policy can be bipartisan, the politics cannot. And in that sense, this year shows little sign of ending on Dec. 31. When President Obama moved to sanction Russia over its alleged interference in the U. S. election just concluded, some Republicans who had long called for similar or more severe measures could scarcely bring themselves to approve. House Speaker Paul Ryan called the Obama measures ”appropriate” but also ”overdue” and ”a prime example of this administration’s ineffective foreign policy that has left America weaker in the eyes of the world.” Other GOP leaders sounded much the same theme. ”[We have] been urging President Obama for years to take strong action to deter Russia’s worldwide aggression, including its   operations,” wrote Rep. Devin Nunes,  . chairman of the House Intelligence Committee. ”Now with just a few weeks left in office, the president has suddenly decided that some stronger measures are indeed warranted.” Appeari
# ...

# %%
topic_results.shape

# 11,992 articles as in the original dataset, but now with 7 topics along
# Out:
# (11992, 7)

# %%
# we are interesting in the indices which carry the highest proabilities
# arg. marx returns an array in descending order
# so 1 means 100% probability
topic_results.argmax(axis=1)
# Out:
# array([1, 1, 1, ..., 3, 4, 0])

# %%
# creating the column "Topic"
articles['Topic'] = topic_results.argmax(axis=1)

# %%
articles.Topic.nunique()
# Out:
# 7

# %%
articles.Topic.unique() # above you can see these topics by their indices
# Out:
# array([1, 2, 3, 5, 6, 4, 0])

# %%
articles.head(10)
# Out:
#                                              Article  Topic
# 0  In the Washington of 2016, even when the polic...      1
# 1    Donald Trump has used Twitter  —   his prefe...      1
# 2    Donald Trump is unabashedly praising Russian...      1
# 3  Updated at 2:50 p. m. ET, Russian President Vl...      1
# 4  From photography, illustration and video, to d...      2
# 5  I did not want to join yoga class. I hated tho...      3
# 6  With a   who has publicly supported the debunk...      3
# 7  I was standing by the airport exit, debating w...      2
# 8  If movies were trying to be more realistic, pe...      3
# 9  Eighteen years ago, on New Year’s Eve, David F...      2
